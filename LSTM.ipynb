# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
import torch
from torch import nn
from itertools import product

# Load data
df_train = pd.read_csv("data/final_data_with_patterns.csv")
df_test = pd.read_csv("test_data/final_test_data_with_patterns.csv")
feature_cols = [c for c in df_train.columns if c not in ["timestamp", "label"]]

# Encode labels
le = LabelEncoder()
y_train = le.fit_transform(df_train["label"])
y_test_raw = df_test["label"]
mask_known = y_test_raw.isin(le.classes_)
df_test = df_test[mask_known].copy()
y_test = le.transform(df_test["label"])

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(df_train[feature_cols])
X_test = scaler.transform(df_test[feature_cols])

# Sequence builder
def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_len + 1):
        x_win = X[i:i+seq_len]
        y_win = y[i:i+seq_len]
        if np.all(y_win == y_win[0]):
            X_seq.append(x_win)
            y_seq.append(y_win[0])
    return np.array(X_seq), np.array(y_seq)

# LSTM model
class LSTMClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])

# Grid configuration
hidden_sizes = [32, 64, 128, 256]
seq_lens = [2, 5, 10, 20]
batch_sizes = [16, 32, 64, 128]
learning_rates = [0.01, 0.02, 0.001, 0.005]

grid = list(product(hidden_sizes, seq_lens, batch_sizes, learning_rates))
print(f"Starting Grid Search: {len(grid)} combinations...\n")

# Tracking
best_acc = 0.0
best_config = None
results = []

# Grid search loop
for i, (hidden_size, seq_len, batch_size, lr) in enumerate(grid, 1):
    print(f" Run {i}/{len(grid)} - hidden_size={hidden_size}, seq_len={seq_len}, batch_size={batch_size}, lr={lr}")

    # Create sequences
    X_tr_seq, y_tr_seq = create_sequences(X_train, y_train, seq_len)
    X_te_seq, y_te_seq = create_sequences(X_test, y_test, seq_len)

    # Convert to tensors
    X_tr = torch.tensor(X_tr_seq, dtype=torch.float32)
    y_tr = torch.tensor(y_tr_seq, dtype=torch.long)
    X_te = torch.tensor(X_te_seq, dtype=torch.float32)
    y_te = torch.tensor(y_te_seq, dtype=torch.long)

    train_loader = DataLoader(TensorDataset(X_tr, y_tr), batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(TensorDataset(X_te, y_te), batch_size=batch_size)

    # Model setup
    model = LSTMClassifier(input_size=len(feature_cols), hidden_size=hidden_size, num_classes=len(le.classes_))
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Training loop
    for epoch in range(10):
        model.train()
        for xb, yb in train_loader:
            optimizer.zero_grad()
            output = model(xb)
            loss = criterion(output, yb)
            loss.backward()
            optimizer.step()

    # Evaluation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for xb, yb in test_loader:
            pred = model(xb)
            pred_class = torch.argmax(pred, dim=1)
            correct += (pred_class == yb).sum().item()
            total += yb.size(0)

    acc = correct / total
    results.append((hidden_size, seq_len, batch_size, lr, acc))

    if acc > best_acc:
        best_acc = acc
        best_config = (hidden_size, seq_len, batch_size, lr)

    print(f" Accuracy: {acc:.4f}\n")

# Best overall
print(" Best Configuration:")
print(f"  hidden_size={best_config[0]}, seq_len={best_config[1]}, batch_size={best_config[2]}, lr={best_config[3]}")
print(f"  Accuracy: {best_acc:.4f}")

# All results
print("\n All Results:")
for hs, sl, bs, lr_val, a in results:
    print(f"  hs={hs}, sl={sl}, bs={bs}, lr={lr_val} → acc={a:.4f}")

# Find optimal minimal config with acc = 1.0
perfect_configs = [r for r in results if r[4] == 1.0]
if perfect_configs:
    optimal = sorted(
        perfect_configs,
        key=lambda x: (x[0], x[1], x[2], -x[3])  # min hidden, min seq, min batch, max lr
    )[0]

    print("\n Optimal Configuration with 100% Accuracy (Minimal Resources):")
    print(f"  hidden_size={optimal[0]}, seq_len={optimal[1]}, batch_size={optimal[2]}, lr={optimal[3]}")
else:
    print("\n No configuration achieved 100% accuracy.")
# Out:
# 🔍 Starting Grid Search: 256 combinations...
#
# ▶️ Run 1/256 - hidden_size=32, seq_len=2, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9908
#
# ▶️ Run 2/256 - hidden_size=32, seq_len=2, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9934
#
# ▶️ Run 3/256 - hidden_size=32, seq_len=2, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9882
#
# ▶️ Run 4/256 - hidden_size=32, seq_len=2, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 5/256 - hidden_size=32, seq_len=2, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 6/256 - hidden_size=32, seq_len=2, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 7/256 - hidden_size=32, seq_len=2, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9908
#
# ▶️ Run 8/256 - hidden_size=32, seq_len=2, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9934
#
# ▶️ Run 9/256 - hidden_size=32, seq_len=2, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9987
#
# ▶️ Run 10/256 - hidden_size=32, seq_len=2, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 11/256 - hidden_size=32, seq_len=2, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9830
#
# ▶️ Run 12/256 - hidden_size=32, seq_len=2, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9987
#
# ▶️ Run 13/256 - hidden_size=32, seq_len=2, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 14/256 - hidden_size=32, seq_len=2, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 15/256 - hidden_size=32, seq_len=2, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9974
#
# ▶️ Run 16/256 - hidden_size=32, seq_len=2, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9961
#
# ▶️ Run 17/256 - hidden_size=32, seq_len=5, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 18/256 - hidden_size=32, seq_len=5, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 19/256 - hidden_size=32, seq_len=5, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9960
#
# ▶️ Run 20/256 - hidden_size=32, seq_len=5, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9987
#
# ▶️ Run 21/256 - hidden_size=32, seq_len=5, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9881
#
# ▶️ Run 22/256 - hidden_size=32, seq_len=5, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9841
#
# ▶️ Run 23/256 - hidden_size=32, seq_len=5, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9920
#
# ▶️ Run 24/256 - hidden_size=32, seq_len=5, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 25/256 - hidden_size=32, seq_len=5, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 26/256 - hidden_size=32, seq_len=5, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9934
#
# ▶️ Run 27/256 - hidden_size=32, seq_len=5, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9615
#
# ▶️ Run 28/256 - hidden_size=32, seq_len=5, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9814
#
# ▶️ Run 29/256 - hidden_size=32, seq_len=5, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9987
#
# ▶️ Run 30/256 - hidden_size=32, seq_len=5, batch_size=128, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 31/256 - hidden_size=32, seq_len=5, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 32/256 - hidden_size=32, seq_len=5, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 33/256 - hidden_size=32, seq_len=10, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 34/256 - hidden_size=32, seq_len=10, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 35/256 - hidden_size=32, seq_len=10, batch_size=16, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 36/256 - hidden_size=32, seq_len=10, batch_size=16, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 37/256 - hidden_size=32, seq_len=10, batch_size=32, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 38/256 - hidden_size=32, seq_len=10, batch_size=32, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 39/256 - hidden_size=32, seq_len=10, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 40/256 - hidden_size=32, seq_len=10, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 41/256 - hidden_size=32, seq_len=10, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9959
#
# ▶️ Run 42/256 - hidden_size=32, seq_len=10, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 43/256 - hidden_size=32, seq_len=10, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9892
#
# ▶️ Run 44/256 - hidden_size=32, seq_len=10, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 45/256 - hidden_size=32, seq_len=10, batch_size=128, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 46/256 - hidden_size=32, seq_len=10, batch_size=128, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 47/256 - hidden_size=32, seq_len=10, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9878
#
# ▶️ Run 48/256 - hidden_size=32, seq_len=10, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 49/256 - hidden_size=32, seq_len=20, batch_size=16, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 50/256 - hidden_size=32, seq_len=20, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 51/256 - hidden_size=32, seq_len=20, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9845
#
# ▶️ Run 52/256 - hidden_size=32, seq_len=20, batch_size=16, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 53/256 - hidden_size=32, seq_len=20, batch_size=32, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 54/256 - hidden_size=32, seq_len=20, batch_size=32, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 55/256 - hidden_size=32, seq_len=20, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 56/256 - hidden_size=32, seq_len=20, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 57/256 - hidden_size=32, seq_len=20, batch_size=64, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 58/256 - hidden_size=32, seq_len=20, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 59/256 - hidden_size=32, seq_len=20, batch_size=64, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 60/256 - hidden_size=32, seq_len=20, batch_size=64, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 61/256 - hidden_size=32, seq_len=20, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9958
#
# ▶️ Run 62/256 - hidden_size=32, seq_len=20, batch_size=128, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 63/256 - hidden_size=32, seq_len=20, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 64/256 - hidden_size=32, seq_len=20, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 65/256 - hidden_size=64, seq_len=2, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9594
#
# ▶️ Run 66/256 - hidden_size=64, seq_len=2, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9554
#
# ▶️ Run 67/256 - hidden_size=64, seq_len=2, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9646
#
# ▶️ Run 68/256 - hidden_size=64, seq_len=2, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9581
#
# ▶️ Run 69/256 - hidden_size=64, seq_len=2, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 70/256 - hidden_size=64, seq_len=2, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9961
#
# ▶️ Run 71/256 - hidden_size=64, seq_len=2, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9581
#
# ▶️ Run 72/256 - hidden_size=64, seq_len=2, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 73/256 - hidden_size=64, seq_len=2, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 74/256 - hidden_size=64, seq_len=2, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 75/256 - hidden_size=64, seq_len=2, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9961
#
# ▶️ Run 76/256 - hidden_size=64, seq_len=2, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 77/256 - hidden_size=64, seq_len=2, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 78/256 - hidden_size=64, seq_len=2, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 79/256 - hidden_size=64, seq_len=2, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9974
#
# ▶️ Run 80/256 - hidden_size=64, seq_len=2, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 81/256 - hidden_size=64, seq_len=5, batch_size=16, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 82/256 - hidden_size=64, seq_len=5, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9960
#
# ▶️ Run 83/256 - hidden_size=64, seq_len=5, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 84/256 - hidden_size=64, seq_len=5, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9894
#
# ▶️ Run 85/256 - hidden_size=64, seq_len=5, batch_size=32, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 86/256 - hidden_size=64, seq_len=5, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9894
#
# ▶️ Run 87/256 - hidden_size=64, seq_len=5, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9894
#
# ▶️ Run 88/256 - hidden_size=64, seq_len=5, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9987
#
# ▶️ Run 89/256 - hidden_size=64, seq_len=5, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9960
#
# ▶️ Run 90/256 - hidden_size=64, seq_len=5, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9973
#
# ▶️ Run 91/256 - hidden_size=64, seq_len=5, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 92/256 - hidden_size=64, seq_len=5, batch_size=64, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 93/256 - hidden_size=64, seq_len=5, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 94/256 - hidden_size=64, seq_len=5, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9960
#
# ▶️ Run 95/256 - hidden_size=64, seq_len=5, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9814
#
# ▶️ Run 96/256 - hidden_size=64, seq_len=5, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9960
#
# ▶️ Run 97/256 - hidden_size=64, seq_len=10, batch_size=16, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 98/256 - hidden_size=64, seq_len=10, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9878
#
# ▶️ Run 99/256 - hidden_size=64, seq_len=10, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9662
#
# ▶️ Run 100/256 - hidden_size=64, seq_len=10, batch_size=16, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 101/256 - hidden_size=64, seq_len=10, batch_size=32, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 102/256 - hidden_size=64, seq_len=10, batch_size=32, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 103/256 - hidden_size=64, seq_len=10, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9743
#
# ▶️ Run 104/256 - hidden_size=64, seq_len=10, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9959
#
# ▶️ Run 105/256 - hidden_size=64, seq_len=10, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9986
#
# ▶️ Run 106/256 - hidden_size=64, seq_len=10, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 107/256 - hidden_size=64, seq_len=10, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9702
#
# ▶️ Run 108/256 - hidden_size=64, seq_len=10, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9959
#
# ▶️ Run 109/256 - hidden_size=64, seq_len=10, batch_size=128, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 110/256 - hidden_size=64, seq_len=10, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9892
#
# ▶️ Run 111/256 - hidden_size=64, seq_len=10, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9919
#
# ▶️ Run 112/256 - hidden_size=64, seq_len=10, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 113/256 - hidden_size=64, seq_len=20, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9972
#
# ▶️ Run 114/256 - hidden_size=64, seq_len=20, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 115/256 - hidden_size=64, seq_len=20, batch_size=16, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 116/256 - hidden_size=64, seq_len=20, batch_size=16, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 117/256 - hidden_size=64, seq_len=20, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9972
#
# ▶️ Run 118/256 - hidden_size=64, seq_len=20, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9817
#
# ▶️ Run 119/256 - hidden_size=64, seq_len=20, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9647
#
# ▶️ Run 120/256 - hidden_size=64, seq_len=20, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 121/256 - hidden_size=64, seq_len=20, batch_size=64, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 122/256 - hidden_size=64, seq_len=20, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 123/256 - hidden_size=64, seq_len=20, batch_size=64, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 124/256 - hidden_size=64, seq_len=20, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9986
#
# ▶️ Run 125/256 - hidden_size=64, seq_len=20, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9929
#
# ▶️ Run 126/256 - hidden_size=64, seq_len=20, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9972
#
# ▶️ Run 127/256 - hidden_size=64, seq_len=20, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 128/256 - hidden_size=64, seq_len=20, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 129/256 - hidden_size=128, seq_len=2, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9502
#
# ▶️ Run 130/256 - hidden_size=128, seq_len=2, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9869
#
# ▶️ Run 131/256 - hidden_size=128, seq_len=2, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9751
#
# ▶️ Run 132/256 - hidden_size=128, seq_len=2, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9699
#
# ▶️ Run 133/256 - hidden_size=128, seq_len=2, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9882
#
# ▶️ Run 134/256 - hidden_size=128, seq_len=2, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9921
#
# ▶️ Run 135/256 - hidden_size=128, seq_len=2, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9961
#
# ▶️ Run 136/256 - hidden_size=128, seq_len=2, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 137/256 - hidden_size=128, seq_len=2, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9856
#
# ▶️ Run 138/256 - hidden_size=128, seq_len=2, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 139/256 - hidden_size=128, seq_len=2, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9974
#
# ▶️ Run 140/256 - hidden_size=128, seq_len=2, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 141/256 - hidden_size=128, seq_len=2, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9895
#
# ▶️ Run 142/256 - hidden_size=128, seq_len=2, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9974
#
# ▶️ Run 143/256 - hidden_size=128, seq_len=2, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9908
#
# ▶️ Run 144/256 - hidden_size=128, seq_len=2, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9974
#
# ▶️ Run 145/256 - hidden_size=128, seq_len=5, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9907
#
# ▶️ Run 146/256 - hidden_size=128, seq_len=5, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 147/256 - hidden_size=128, seq_len=5, batch_size=16, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 148/256 - hidden_size=128, seq_len=5, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9934
#
# ▶️ Run 149/256 - hidden_size=128, seq_len=5, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9987
#
# ▶️ Run 150/256 - hidden_size=128, seq_len=5, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9960
#
# ▶️ Run 151/256 - hidden_size=128, seq_len=5, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 152/256 - hidden_size=128, seq_len=5, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 153/256 - hidden_size=128, seq_len=5, batch_size=64, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 154/256 - hidden_size=128, seq_len=5, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9881
#
# ▶️ Run 155/256 - hidden_size=128, seq_len=5, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9960
#
# ▶️ Run 156/256 - hidden_size=128, seq_len=5, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9987
#
# ▶️ Run 157/256 - hidden_size=128, seq_len=5, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9987
#
# ▶️ Run 158/256 - hidden_size=128, seq_len=5, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9920
#
# ▶️ Run 159/256 - hidden_size=128, seq_len=5, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 160/256 - hidden_size=128, seq_len=5, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 161/256 - hidden_size=128, seq_len=10, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 162/256 - hidden_size=128, seq_len=10, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9986
#
# ▶️ Run 163/256 - hidden_size=128, seq_len=10, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9986
#
# ▶️ Run 164/256 - hidden_size=128, seq_len=10, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 165/256 - hidden_size=128, seq_len=10, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 166/256 - hidden_size=128, seq_len=10, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9865
#
# ▶️ Run 167/256 - hidden_size=128, seq_len=10, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 168/256 - hidden_size=128, seq_len=10, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9959
#
# ▶️ Run 169/256 - hidden_size=128, seq_len=10, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9986
#
# ▶️ Run 170/256 - hidden_size=128, seq_len=10, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 171/256 - hidden_size=128, seq_len=10, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9865
#
# ▶️ Run 172/256 - hidden_size=128, seq_len=10, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 173/256 - hidden_size=128, seq_len=10, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9946
#
# ▶️ Run 174/256 - hidden_size=128, seq_len=10, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9986
#
# ▶️ Run 175/256 - hidden_size=128, seq_len=10, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9986
#
# ▶️ Run 176/256 - hidden_size=128, seq_len=10, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9986
#
# ▶️ Run 177/256 - hidden_size=128, seq_len=20, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9986
#
# ▶️ Run 178/256 - hidden_size=128, seq_len=20, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9901
#
# ▶️ Run 179/256 - hidden_size=128, seq_len=20, batch_size=16, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 180/256 - hidden_size=128, seq_len=20, batch_size=16, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 181/256 - hidden_size=128, seq_len=20, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9986
#
# ▶️ Run 182/256 - hidden_size=128, seq_len=20, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9929
#
# ▶️ Run 183/256 - hidden_size=128, seq_len=20, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 184/256 - hidden_size=128, seq_len=20, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9929
#
# ▶️ Run 185/256 - hidden_size=128, seq_len=20, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9873
#
# ▶️ Run 186/256 - hidden_size=128, seq_len=20, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9972
#
# ▶️ Run 187/256 - hidden_size=128, seq_len=20, batch_size=64, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 188/256 - hidden_size=128, seq_len=20, batch_size=64, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 189/256 - hidden_size=128, seq_len=20, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9873
#
# ▶️ Run 190/256 - hidden_size=128, seq_len=20, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9986
#
# ▶️ Run 191/256 - hidden_size=128, seq_len=20, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 192/256 - hidden_size=128, seq_len=20, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9944
#
# ▶️ Run 193/256 - hidden_size=256, seq_len=2, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9974
#
# ▶️ Run 194/256 - hidden_size=256, seq_len=2, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 195/256 - hidden_size=256, seq_len=2, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9567
#
# ▶️ Run 196/256 - hidden_size=256, seq_len=2, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9463
#
# ▶️ Run 197/256 - hidden_size=256, seq_len=2, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9436
#
# ▶️ Run 198/256 - hidden_size=256, seq_len=2, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9882
#
# ▶️ Run 199/256 - hidden_size=256, seq_len=2, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9882
#
# ▶️ Run 200/256 - hidden_size=256, seq_len=2, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9908
#
# ▶️ Run 201/256 - hidden_size=256, seq_len=2, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9908
#
# ▶️ Run 202/256 - hidden_size=256, seq_len=2, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9987
#
# ▶️ Run 203/256 - hidden_size=256, seq_len=2, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9921
#
# ▶️ Run 204/256 - hidden_size=256, seq_len=2, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9908
#
# ▶️ Run 205/256 - hidden_size=256, seq_len=2, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9908
#
# ▶️ Run 206/256 - hidden_size=256, seq_len=2, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9948
#
# ▶️ Run 207/256 - hidden_size=256, seq_len=2, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9895
#
# ▶️ Run 208/256 - hidden_size=256, seq_len=2, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9934
#
# ▶️ Run 209/256 - hidden_size=256, seq_len=5, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9894
#
# ▶️ Run 210/256 - hidden_size=256, seq_len=5, batch_size=16, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 211/256 - hidden_size=256, seq_len=5, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 212/256 - hidden_size=256, seq_len=5, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9987
#
# ▶️ Run 213/256 - hidden_size=256, seq_len=5, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 214/256 - hidden_size=256, seq_len=5, batch_size=32, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 215/256 - hidden_size=256, seq_len=5, batch_size=32, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 216/256 - hidden_size=256, seq_len=5, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 217/256 - hidden_size=256, seq_len=5, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9867
#
# ▶️ Run 218/256 - hidden_size=256, seq_len=5, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 219/256 - hidden_size=256, seq_len=5, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 220/256 - hidden_size=256, seq_len=5, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9483
#
# ▶️ Run 221/256 - hidden_size=256, seq_len=5, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9973
#
# ▶️ Run 222/256 - hidden_size=256, seq_len=5, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9960
#
# ▶️ Run 223/256 - hidden_size=256, seq_len=5, batch_size=128, lr=0.001
# ✅ Accuracy: 0.9987
#
# ▶️ Run 224/256 - hidden_size=256, seq_len=5, batch_size=128, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 225/256 - hidden_size=256, seq_len=10, batch_size=16, lr=0.01
# ✅ Accuracy: 0.9459
#
# ▶️ Run 226/256 - hidden_size=256, seq_len=10, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9675
#
# ▶️ Run 227/256 - hidden_size=256, seq_len=10, batch_size=16, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 228/256 - hidden_size=256, seq_len=10, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9973
#
# ▶️ Run 229/256 - hidden_size=256, seq_len=10, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9797
#
# ▶️ Run 230/256 - hidden_size=256, seq_len=10, batch_size=32, lr=0.02
# ✅ Accuracy: 0.9892
#
# ▶️ Run 231/256 - hidden_size=256, seq_len=10, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 232/256 - hidden_size=256, seq_len=10, batch_size=32, lr=0.005
# ✅ Accuracy: 0.9946
#
# ▶️ Run 233/256 - hidden_size=256, seq_len=10, batch_size=64, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 234/256 - hidden_size=256, seq_len=10, batch_size=64, lr=0.02
# ✅ Accuracy: 0.9892
#
# ▶️ Run 235/256 - hidden_size=256, seq_len=10, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9986
#
# ▶️ Run 236/256 - hidden_size=256, seq_len=10, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9986
#
# ▶️ Run 237/256 - hidden_size=256, seq_len=10, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9892
#
# ▶️ Run 238/256 - hidden_size=256, seq_len=10, batch_size=128, lr=0.02
# ✅ Accuracy: 0.9323
#
# ▶️ Run 239/256 - hidden_size=256, seq_len=10, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 240/256 - hidden_size=256, seq_len=10, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9905
#
# ▶️ Run 241/256 - hidden_size=256, seq_len=20, batch_size=16, lr=0.01
# ✅ Accuracy: 1.0000
#
# ▶️ Run 242/256 - hidden_size=256, seq_len=20, batch_size=16, lr=0.02
# ✅ Accuracy: 0.9972
#
# ▶️ Run 243/256 - hidden_size=256, seq_len=20, batch_size=16, lr=0.001
# ✅ Accuracy: 0.9986
#
# ▶️ Run 244/256 - hidden_size=256, seq_len=20, batch_size=16, lr=0.005
# ✅ Accuracy: 0.9929
#
# ▶️ Run 245/256 - hidden_size=256, seq_len=20, batch_size=32, lr=0.01
# ✅ Accuracy: 0.9887
#
# ▶️ Run 246/256 - hidden_size=256, seq_len=20, batch_size=32, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 247/256 - hidden_size=256, seq_len=20, batch_size=32, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 248/256 - hidden_size=256, seq_len=20, batch_size=32, lr=0.005
# ✅ Accuracy: 1.0000
#
# ▶️ Run 249/256 - hidden_size=256, seq_len=20, batch_size=64, lr=0.01
# ✅ Accuracy: 0.9972
#
# ▶️ Run 250/256 - hidden_size=256, seq_len=20, batch_size=64, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 251/256 - hidden_size=256, seq_len=20, batch_size=64, lr=0.001
# ✅ Accuracy: 0.9944
#
# ▶️ Run 252/256 - hidden_size=256, seq_len=20, batch_size=64, lr=0.005
# ✅ Accuracy: 0.9986
#
# ▶️ Run 253/256 - hidden_size=256, seq_len=20, batch_size=128, lr=0.01
# ✅ Accuracy: 0.9901
#
# ▶️ Run 254/256 - hidden_size=256, seq_len=20, batch_size=128, lr=0.02
# ✅ Accuracy: 1.0000
#
# ▶️ Run 255/256 - hidden_size=256, seq_len=20, batch_size=128, lr=0.001
# ✅ Accuracy: 1.0000
#
# ▶️ Run 256/256 - hidden_size=256, seq_len=20, batch_size=128, lr=0.005
# ✅ Accuracy: 0.9873
#
# 🎯 Best Configuration:
#   hidden_size=32, seq_len=5, batch_size=16, lr=0.02
#   Accuracy: 1.0000
#
# 📊 All Results:
#   hs=32, sl=2, bs=16, lr=0.01 → acc=0.9908
#   hs=32, sl=2, bs=16, lr=0.02 → acc=0.9934
#   hs=32, sl=2, bs=16, lr=0.001 → acc=0.9882
#   hs=32, sl=2, bs=16, lr=0.005 → acc=0.9974
#   hs=32, sl=2, bs=32, lr=0.01 → acc=0.9974
#   hs=32, sl=2, bs=32, lr=0.02 → acc=0.9974
#   hs=32, sl=2, bs=32, lr=0.001 → acc=0.9908
#   hs=32, sl=2, bs=32, lr=0.005 → acc=0.9934
#   hs=32, sl=2, bs=64, lr=0.01 → acc=0.9987
#   hs=32, sl=2, bs=64, lr=0.02 → acc=0.9974
#   hs=32, sl=2, bs=64, lr=0.001 → acc=0.9830
#   hs=32, sl=2, bs=64, lr=0.005 → acc=0.9987
#   hs=32, sl=2, bs=128, lr=0.01 → acc=0.9974
#   hs=32, sl=2, bs=128, lr=0.02 → acc=0.9974
#   hs=32, sl=2, bs=128, lr=0.001 → acc=0.9974
#   hs=32, sl=2, bs=128, lr=0.005 → acc=0.9961
#   hs=32, sl=5, bs=16, lr=0.01 → acc=0.9973
#   hs=32, sl=5, bs=16, lr=0.02 → acc=1.0000
#   hs=32, sl=5, bs=16, lr=0.001 → acc=0.9960
#   hs=32, sl=5, bs=16, lr=0.005 → acc=0.9987
#   hs=32, sl=5, bs=32, lr=0.01 → acc=0.9881
#   hs=32, sl=5, bs=32, lr=0.02 → acc=0.9841
#   hs=32, sl=5, bs=32, lr=0.001 → acc=0.9920
#   hs=32, sl=5, bs=32, lr=0.005 → acc=1.0000
#   hs=32, sl=5, bs=64, lr=0.01 → acc=0.9973
#   hs=32, sl=5, bs=64, lr=0.02 → acc=0.9934
#   hs=32, sl=5, bs=64, lr=0.001 → acc=0.9615
#   hs=32, sl=5, bs=64, lr=0.005 → acc=0.9814
#   hs=32, sl=5, bs=128, lr=0.01 → acc=0.9987
#   hs=32, sl=5, bs=128, lr=0.02 → acc=1.0000
#   hs=32, sl=5, bs=128, lr=0.001 → acc=1.0000
#   hs=32, sl=5, bs=128, lr=0.005 → acc=1.0000
#   hs=32, sl=10, bs=16, lr=0.01 → acc=0.9973
#   hs=32, sl=10, bs=16, lr=0.02 → acc=1.0000
#   hs=32, sl=10, bs=16, lr=0.001 → acc=1.0000
#   hs=32, sl=10, bs=16, lr=0.005 → acc=1.0000
#   hs=32, sl=10, bs=32, lr=0.01 → acc=1.0000
#   hs=32, sl=10, bs=32, lr=0.02 → acc=1.0000
#   hs=32, sl=10, bs=32, lr=0.001 → acc=1.0000
#   hs=32, sl=10, bs=32, lr=0.005 → acc=1.0000
#   hs=32, sl=10, bs=64, lr=0.01 → acc=0.9959
#   hs=32, sl=10, bs=64, lr=0.02 → acc=1.0000
#   hs=32, sl=10, bs=64, lr=0.001 → acc=0.9892
#   hs=32, sl=10, bs=64, lr=0.005 → acc=0.9973
#   hs=32, sl=10, bs=128, lr=0.01 → acc=1.0000
#   hs=32, sl=10, bs=128, lr=0.02 → acc=1.0000
#   hs=32, sl=10, bs=128, lr=0.001 → acc=0.9878
#   hs=32, sl=10, bs=128, lr=0.005 → acc=1.0000
#   hs=32, sl=20, bs=16, lr=0.01 → acc=1.0000
#   hs=32, sl=20, bs=16, lr=0.02 → acc=1.0000
#   hs=32, sl=20, bs=16, lr=0.001 → acc=0.9845
#   hs=32, sl=20, bs=16, lr=0.005 → acc=1.0000
#   hs=32, sl=20, bs=32, lr=0.01 → acc=1.0000
#   hs=32, sl=20, bs=32, lr=0.02 → acc=1.0000
#   hs=32, sl=20, bs=32, lr=0.001 → acc=1.0000
#   hs=32, sl=20, bs=32, lr=0.005 → acc=1.0000
#   hs=32, sl=20, bs=64, lr=0.01 → acc=1.0000
#   hs=32, sl=20, bs=64, lr=0.02 → acc=1.0000
#   hs=32, sl=20, bs=64, lr=0.001 → acc=1.0000
#   hs=32, sl=20, bs=64, lr=0.005 → acc=1.0000
#   hs=32, sl=20, bs=128, lr=0.01 → acc=0.9958
#   hs=32, sl=20, bs=128, lr=0.02 → acc=1.0000
#   hs=32, sl=20, bs=128, lr=0.001 → acc=1.0000
#   hs=32, sl=20, bs=128, lr=0.005 → acc=1.0000
#   hs=64, sl=2, bs=16, lr=0.01 → acc=0.9594
#   hs=64, sl=2, bs=16, lr=0.02 → acc=0.9554
#   hs=64, sl=2, bs=16, lr=0.001 → acc=0.9646
#   hs=64, sl=2, bs=16, lr=0.005 → acc=0.9581
#   hs=64, sl=2, bs=32, lr=0.01 → acc=0.9974
#   hs=64, sl=2, bs=32, lr=0.02 → acc=0.9961
#   hs=64, sl=2, bs=32, lr=0.001 → acc=0.9581
#   hs=64, sl=2, bs=32, lr=0.005 → acc=0.9974
#   hs=64, sl=2, bs=64, lr=0.01 → acc=0.9974
#   hs=64, sl=2, bs=64, lr=0.02 → acc=0.9974
#   hs=64, sl=2, bs=64, lr=0.001 → acc=0.9961
#   hs=64, sl=2, bs=64, lr=0.005 → acc=0.9974
#   hs=64, sl=2, bs=128, lr=0.01 → acc=0.9974
#   hs=64, sl=2, bs=128, lr=0.02 → acc=0.9974
#   hs=64, sl=2, bs=128, lr=0.001 → acc=0.9974
#   hs=64, sl=2, bs=128, lr=0.005 → acc=0.9974
#   hs=64, sl=5, bs=16, lr=0.01 → acc=1.0000
#   hs=64, sl=5, bs=16, lr=0.02 → acc=0.9960
#   hs=64, sl=5, bs=16, lr=0.001 → acc=0.9987
#   hs=64, sl=5, bs=16, lr=0.005 → acc=0.9894
#   hs=64, sl=5, bs=32, lr=0.01 → acc=1.0000
#   hs=64, sl=5, bs=32, lr=0.02 → acc=0.9894
#   hs=64, sl=5, bs=32, lr=0.001 → acc=0.9894
#   hs=64, sl=5, bs=32, lr=0.005 → acc=0.9987
#   hs=64, sl=5, bs=64, lr=0.01 → acc=0.9960
#   hs=64, sl=5, bs=64, lr=0.02 → acc=0.9973
#   hs=64, sl=5, bs=64, lr=0.001 → acc=0.9987
#   hs=64, sl=5, bs=64, lr=0.005 → acc=1.0000
#   hs=64, sl=5, bs=128, lr=0.01 → acc=0.9973
#   hs=64, sl=5, bs=128, lr=0.02 → acc=0.9960
#   hs=64, sl=5, bs=128, lr=0.001 → acc=0.9814
#   hs=64, sl=5, bs=128, lr=0.005 → acc=0.9960
#   hs=64, sl=10, bs=16, lr=0.01 → acc=1.0000
#   hs=64, sl=10, bs=16, lr=0.02 → acc=0.9878
#   hs=64, sl=10, bs=16, lr=0.001 → acc=0.9662
#   hs=64, sl=10, bs=16, lr=0.005 → acc=1.0000
#   hs=64, sl=10, bs=32, lr=0.01 → acc=1.0000
#   hs=64, sl=10, bs=32, lr=0.02 → acc=1.0000
#   hs=64, sl=10, bs=32, lr=0.001 → acc=0.9743
#   hs=64, sl=10, bs=32, lr=0.005 → acc=0.9959
#   hs=64, sl=10, bs=64, lr=0.01 → acc=0.9986
#   hs=64, sl=10, bs=64, lr=0.02 → acc=1.0000
#   hs=64, sl=10, bs=64, lr=0.001 → acc=0.9702
#   hs=64, sl=10, bs=64, lr=0.005 → acc=0.9959
#   hs=64, sl=10, bs=128, lr=0.01 → acc=1.0000
#   hs=64, sl=10, bs=128, lr=0.02 → acc=0.9892
#   hs=64, sl=10, bs=128, lr=0.001 → acc=0.9919
#   hs=64, sl=10, bs=128, lr=0.005 → acc=1.0000
#   hs=64, sl=20, bs=16, lr=0.01 → acc=0.9972
#   hs=64, sl=20, bs=16, lr=0.02 → acc=1.0000
#   hs=64, sl=20, bs=16, lr=0.001 → acc=1.0000
#   hs=64, sl=20, bs=16, lr=0.005 → acc=1.0000
#   hs=64, sl=20, bs=32, lr=0.01 → acc=0.9972
#   hs=64, sl=20, bs=32, lr=0.02 → acc=0.9817
#   hs=64, sl=20, bs=32, lr=0.001 → acc=0.9647
#   hs=64, sl=20, bs=32, lr=0.005 → acc=1.0000
#   hs=64, sl=20, bs=64, lr=0.01 → acc=1.0000
#   hs=64, sl=20, bs=64, lr=0.02 → acc=1.0000
#   hs=64, sl=20, bs=64, lr=0.001 → acc=1.0000
#   hs=64, sl=20, bs=64, lr=0.005 → acc=0.9986
#   hs=64, sl=20, bs=128, lr=0.01 → acc=0.9929
#   hs=64, sl=20, bs=128, lr=0.02 → acc=0.9972
#   hs=64, sl=20, bs=128, lr=0.001 → acc=1.0000
#   hs=64, sl=20, bs=128, lr=0.005 → acc=1.0000
#   hs=128, sl=2, bs=16, lr=0.01 → acc=0.9502
#   hs=128, sl=2, bs=16, lr=0.02 → acc=0.9869
#   hs=128, sl=2, bs=16, lr=0.001 → acc=0.9751
#   hs=128, sl=2, bs=16, lr=0.005 → acc=0.9699
#   hs=128, sl=2, bs=32, lr=0.01 → acc=0.9882
#   hs=128, sl=2, bs=32, lr=0.02 → acc=0.9921
#   hs=128, sl=2, bs=32, lr=0.001 → acc=0.9961
#   hs=128, sl=2, bs=32, lr=0.005 → acc=0.9974
#   hs=128, sl=2, bs=64, lr=0.01 → acc=0.9856
#   hs=128, sl=2, bs=64, lr=0.02 → acc=0.9974
#   hs=128, sl=2, bs=64, lr=0.001 → acc=0.9974
#   hs=128, sl=2, bs=64, lr=0.005 → acc=0.9974
#   hs=128, sl=2, bs=128, lr=0.01 → acc=0.9895
#   hs=128, sl=2, bs=128, lr=0.02 → acc=0.9974
#   hs=128, sl=2, bs=128, lr=0.001 → acc=0.9908
#   hs=128, sl=2, bs=128, lr=0.005 → acc=0.9974
#   hs=128, sl=5, bs=16, lr=0.01 → acc=0.9907
#   hs=128, sl=5, bs=16, lr=0.02 → acc=1.0000
#   hs=128, sl=5, bs=16, lr=0.001 → acc=1.0000
#   hs=128, sl=5, bs=16, lr=0.005 → acc=0.9934
#   hs=128, sl=5, bs=32, lr=0.01 → acc=0.9987
#   hs=128, sl=5, bs=32, lr=0.02 → acc=0.9960
#   hs=128, sl=5, bs=32, lr=0.001 → acc=0.9987
#   hs=128, sl=5, bs=32, lr=0.005 → acc=0.9973
#   hs=128, sl=5, bs=64, lr=0.01 → acc=1.0000
#   hs=128, sl=5, bs=64, lr=0.02 → acc=0.9881
#   hs=128, sl=5, bs=64, lr=0.001 → acc=0.9960
#   hs=128, sl=5, bs=64, lr=0.005 → acc=0.9987
#   hs=128, sl=5, bs=128, lr=0.01 → acc=0.9987
#   hs=128, sl=5, bs=128, lr=0.02 → acc=0.9920
#   hs=128, sl=5, bs=128, lr=0.001 → acc=1.0000
#   hs=128, sl=5, bs=128, lr=0.005 → acc=0.9973
#   hs=128, sl=10, bs=16, lr=0.01 → acc=0.9973
#   hs=128, sl=10, bs=16, lr=0.02 → acc=0.9986
#   hs=128, sl=10, bs=16, lr=0.001 → acc=0.9986
#   hs=128, sl=10, bs=16, lr=0.005 → acc=0.9973
#   hs=128, sl=10, bs=32, lr=0.01 → acc=0.9973
#   hs=128, sl=10, bs=32, lr=0.02 → acc=0.9865
#   hs=128, sl=10, bs=32, lr=0.001 → acc=1.0000
#   hs=128, sl=10, bs=32, lr=0.005 → acc=0.9959
#   hs=128, sl=10, bs=64, lr=0.01 → acc=0.9986
#   hs=128, sl=10, bs=64, lr=0.02 → acc=1.0000
#   hs=128, sl=10, bs=64, lr=0.001 → acc=0.9865
#   hs=128, sl=10, bs=64, lr=0.005 → acc=0.9973
#   hs=128, sl=10, bs=128, lr=0.01 → acc=0.9946
#   hs=128, sl=10, bs=128, lr=0.02 → acc=0.9986
#   hs=128, sl=10, bs=128, lr=0.001 → acc=0.9986
#   hs=128, sl=10, bs=128, lr=0.005 → acc=0.9986
#   hs=128, sl=20, bs=16, lr=0.01 → acc=0.9986
#   hs=128, sl=20, bs=16, lr=0.02 → acc=0.9901
#   hs=128, sl=20, bs=16, lr=0.001 → acc=1.0000
#   hs=128, sl=20, bs=16, lr=0.005 → acc=1.0000
#   hs=128, sl=20, bs=32, lr=0.01 → acc=0.9986
#   hs=128, sl=20, bs=32, lr=0.02 → acc=0.9929
#   hs=128, sl=20, bs=32, lr=0.001 → acc=1.0000
#   hs=128, sl=20, bs=32, lr=0.005 → acc=0.9929
#   hs=128, sl=20, bs=64, lr=0.01 → acc=0.9873
#   hs=128, sl=20, bs=64, lr=0.02 → acc=0.9972
#   hs=128, sl=20, bs=64, lr=0.001 → acc=1.0000
#   hs=128, sl=20, bs=64, lr=0.005 → acc=1.0000
#   hs=128, sl=20, bs=128, lr=0.01 → acc=0.9873
#   hs=128, sl=20, bs=128, lr=0.02 → acc=0.9986
#   hs=128, sl=20, bs=128, lr=0.001 → acc=1.0000
#   hs=128, sl=20, bs=128, lr=0.005 → acc=0.9944
#   hs=256, sl=2, bs=16, lr=0.01 → acc=0.9974
#   hs=256, sl=2, bs=16, lr=0.02 → acc=1.0000
#   hs=256, sl=2, bs=16, lr=0.001 → acc=0.9567
#   hs=256, sl=2, bs=16, lr=0.005 → acc=0.9463
#   hs=256, sl=2, bs=32, lr=0.01 → acc=0.9436
#   hs=256, sl=2, bs=32, lr=0.02 → acc=0.9882
#   hs=256, sl=2, bs=32, lr=0.001 → acc=0.9882
#   hs=256, sl=2, bs=32, lr=0.005 → acc=0.9908
#   hs=256, sl=2, bs=64, lr=0.01 → acc=0.9908
#   hs=256, sl=2, bs=64, lr=0.02 → acc=0.9987
#   hs=256, sl=2, bs=64, lr=0.001 → acc=0.9921
#   hs=256, sl=2, bs=64, lr=0.005 → acc=0.9908
#   hs=256, sl=2, bs=128, lr=0.01 → acc=0.9908
#   hs=256, sl=2, bs=128, lr=0.02 → acc=0.9948
#   hs=256, sl=2, bs=128, lr=0.001 → acc=0.9895
#   hs=256, sl=2, bs=128, lr=0.005 → acc=0.9934
#   hs=256, sl=5, bs=16, lr=0.01 → acc=0.9894
#   hs=256, sl=5, bs=16, lr=0.02 → acc=1.0000
#   hs=256, sl=5, bs=16, lr=0.001 → acc=0.9987
#   hs=256, sl=5, bs=16, lr=0.005 → acc=0.9987
#   hs=256, sl=5, bs=32, lr=0.01 → acc=0.9973
#   hs=256, sl=5, bs=32, lr=0.02 → acc=1.0000
#   hs=256, sl=5, bs=32, lr=0.001 → acc=0.9987
#   hs=256, sl=5, bs=32, lr=0.005 → acc=1.0000
#   hs=256, sl=5, bs=64, lr=0.01 → acc=0.9867
#   hs=256, sl=5, bs=64, lr=0.02 → acc=1.0000
#   hs=256, sl=5, bs=64, lr=0.001 → acc=0.9987
#   hs=256, sl=5, bs=64, lr=0.005 → acc=0.9483
#   hs=256, sl=5, bs=128, lr=0.01 → acc=0.9973
#   hs=256, sl=5, bs=128, lr=0.02 → acc=0.9960
#   hs=256, sl=5, bs=128, lr=0.001 → acc=0.9987
#   hs=256, sl=5, bs=128, lr=0.005 → acc=1.0000
#   hs=256, sl=10, bs=16, lr=0.01 → acc=0.9459
#   hs=256, sl=10, bs=16, lr=0.02 → acc=0.9675
#   hs=256, sl=10, bs=16, lr=0.001 → acc=1.0000
#   hs=256, sl=10, bs=16, lr=0.005 → acc=0.9973
#   hs=256, sl=10, bs=32, lr=0.01 → acc=0.9797
#   hs=256, sl=10, bs=32, lr=0.02 → acc=0.9892
#   hs=256, sl=10, bs=32, lr=0.001 → acc=1.0000
#   hs=256, sl=10, bs=32, lr=0.005 → acc=0.9946
#   hs=256, sl=10, bs=64, lr=0.01 → acc=1.0000
#   hs=256, sl=10, bs=64, lr=0.02 → acc=0.9892
#   hs=256, sl=10, bs=64, lr=0.001 → acc=0.9986
#   hs=256, sl=10, bs=64, lr=0.005 → acc=0.9986
#   hs=256, sl=10, bs=128, lr=0.01 → acc=0.9892
#   hs=256, sl=10, bs=128, lr=0.02 → acc=0.9323
#   hs=256, sl=10, bs=128, lr=0.001 → acc=1.0000
#   hs=256, sl=10, bs=128, lr=0.005 → acc=0.9905
#   hs=256, sl=20, bs=16, lr=0.01 → acc=1.0000
#   hs=256, sl=20, bs=16, lr=0.02 → acc=0.9972
#   hs=256, sl=20, bs=16, lr=0.001 → acc=0.9986
#   hs=256, sl=20, bs=16, lr=0.005 → acc=0.9929
#   hs=256, sl=20, bs=32, lr=0.01 → acc=0.9887
#   hs=256, sl=20, bs=32, lr=0.02 → acc=1.0000
#   hs=256, sl=20, bs=32, lr=0.001 → acc=1.0000
#   hs=256, sl=20, bs=32, lr=0.005 → acc=1.0000
#   hs=256, sl=20, bs=64, lr=0.01 → acc=0.9972
#   hs=256, sl=20, bs=64, lr=0.02 → acc=1.0000
#   hs=256, sl=20, bs=64, lr=0.001 → acc=0.9944
#   hs=256, sl=20, bs=64, lr=0.005 → acc=0.9986
#   hs=256, sl=20, bs=128, lr=0.01 → acc=0.9901
#   hs=256, sl=20, bs=128, lr=0.02 → acc=1.0000
#   hs=256, sl=20, bs=128, lr=0.001 → acc=1.0000
#   hs=256, sl=20, bs=128, lr=0.005 → acc=0.9873
#
# 🏆 Optimal Configuration with 100% Accuracy (Minimal Resources):
#   hidden_size=32, seq_len=5, batch_size=16, lr=0.02

# %%
# Recalculate computationally optimal config from saved results
perfect_configs = [r for r in results if r[4] == 1.0]

if perfect_configs:
    optimal = sorted(
        perfect_configs,
        key=lambda x: (x[0], x[1], x[2], -x[3])
    )[0]

    print("\n Optimal Configuration with 100% Accuracy (Least Cost):")
    print(f"  hidden_size = {optimal[0]}")
    print(f"  seq_len     = {optimal[1]}")
    print(f"  batch_size  = {optimal[2]}")
    print(f"  learning_rate = {optimal[3]}")
else:
    print("\n⚠ No configuration achieved 100% accuracy.")
# Out:
#  Optimal Configuration with 100% Accuracy (Least Cost):
#   hidden_size = 32
#   seq_len     = 5
#   batch_size  = 16
#   learning_rate = 0.02
